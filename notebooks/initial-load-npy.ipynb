# %%
import numpy as np

arr = np.load("../data/raw/Skeleton_data/V1.npy")
print(arr.shape)
print(arr.dtype)
print(arr.ndim)
print(arr[0].shape)
print(arr[0, 0])
# Out:
# (1866, 25, 17, 2)
# float64
# 4
# (25, 17, 2)
# [[0.34567585 0.29479864]
#  [0.34258716 0.30028964]
#  [0.34258716 0.27832567]
#  [0.34876454 0.39912749]
#  [0.32096639 0.26185271]
#  [0.30861166 0.31127165]
#  [0.28081355 0.32774461]
#  [0.31787772 0.42658246]
#  [0.30861166 0.45952839]
#  [0.34258716 0.37167252]
#  [0.34258716 0.37716353]
#  [0.29934564 0.54738422]
#  [0.2684588  0.55287522]
#  [0.33949847 0.67367698]
#  [0.28390222 0.73407779]
#  [0.33332112 0.81095166]
#  [0.24066067 0.9262625 ]]
# 1866
